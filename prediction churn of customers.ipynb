# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)
from datetime import datetime, timedelta
import time
import re
# %matplotlib inline

# %%
df = pd.read_csv('BankChurners.csv', low_memory = False)
df
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
df.shape
# Out:
# (10127, 23)

# %%
df.dtypes
# Out:
# CLIENTNUM                                                                                                                               int64
# Attrition_Flag                                                                                                                         object
# Customer_Age                                                                                                                            int64
# Gender                                                                                                                                 object
# Dependent_count                                                                                                                         int64
# Education_Level                                                                                                                        object
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 23 columns):
#  #   Column                                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                                              --------------  -----
#  0   CLIENTNUM                                                                                                                           10127 non-null  int64
#  1   Attrition_Flag                                                                                                                      10127 non-null  object
#  2   Customer_Age                                                                                                                        10127 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# CLIENTNUM                                                                                                                             0
# Attrition_Flag                                                                                                                        0
# Customer_Age                                                                                                                          0
# Gender                                                                                                                                0
# Dependent_count                                                                                                                       0
# Education_Level                                                                                                                       0
# Marital_Status                                                                                                                        0
# ...

# %%
correlation = df.corr()
correlation.head()
# Out:
#                           CLIENTNUM  Customer_Age  Dependent_count  \
# CLIENTNUM                  1.000000      0.007613         0.006772
# Customer_Age               0.007613      1.000000        -0.122254
# Dependent_count            0.006772     -0.122254         1.000000
# Months_on_book             0.134588      0.788912        -0.103062
# Total_Relationship_Count   0.006907     -0.010931        -0.039076
#
#                           Months_on_book  Total_Relationship_Count  \
# CLIENTNUM                       0.134588                  0.006907
# Customer_Age                    0.788912                 -0.010931
# Dependent_count                -0.103062                 -0.039076
# Months_on_book                  1.000000                 -0.009203
# Total_Relationship_Count       -0.009203                  1.000000
#
#                           Months_Inactive_12_mon  Contacts_Count_12_mon  \
# CLIENTNUM                               0.005729               0.005694
# ...

# %%
sns.heatmap(correlation, annot = True)
plt.show()

# %%
# the requested matter is to predit if a customer is going to churn, so we split the customers into two groups. 

df['Attrition_Flag'] = df['Attrition_Flag'].apply(lambda x : 1 if x == 'Existing Customer' else 0)
df
# Out:
#        CLIENTNUM  Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383               1            45      M                3
# 1      818770008               1            49      F                5
# 2      713982108               1            51      M                3
# 3      769911858               1            40      F                4
# 4      709106358               1            40      M                3
# ...          ...             ...           ...    ...              ...
# 10122  772366833               1            50      M                2
# 10123  710638233               0            41      M                2
# 10124  716506083               0            44      F                1
# 10125  717406983               0            30      M                2
# 10126  714337233               0            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
#Dummy variables are useful because they enable us to use a single regression equation to represent multiple groups. 
#This means that we don't need to write out separate equation models for each subgroup. 
#The dummy variables act like 'switches' that turn various parameters on and off in an equation.


df = pd.get_dummies(df, columns = ['Education_Level', 'Marital_Status', 'Card_Category', 'Gender', 'Income_Category'])
df
# Out:
#        CLIENTNUM  Attrition_Flag  Customer_Age  Dependent_count  \
# 0      768805383               1            45                3
# 1      818770008               1            49                5
# 2      713982108               1            51                3
# 3      769911858               1            40                4
# 4      709106358               1            40                3
# ...          ...             ...           ...              ...
# 10122  772366833               1            50                2
# 10123  710638233               0            41                2
# 10124  716506083               0            44                1
# 10125  717406983               0            30                2
# 10126  714337233               0            43                2
#
#        Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# 0                  39                         5                       1
# ...

# %%
from sklearn.model_selection import train_test_split # splitting the data into training and test set.

X = df.drop(['Attrition_Flag'], axis = 1)
y = df['Attrition_Flag']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
#feature scaling


from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.fit_transform(X_test)

# %%
#building the model


from sklearn.linear_model import LogisticRegression

from sklearn.metrics import classification_report

# %%
#creating an instance of a Logistic Regression model

model = LogisticRegression(random_state = 0)

# %%
#training the model

model.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
#predicting the results

y_pred = model.predict(X_test)

# %%
#evaluating the model

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       309
#            1       1.00      1.00      1.00      1717
#
#     accuracy                           1.00      2026
#    macro avg       1.00      1.00      1.00      2026
# weighted avg       1.00      1.00      1.00      2026

# %%
#Accuracy = 1 in sklearn machine learning means that the model has predicted all of the sample data perfectly. 
#This is usually not a realistic outcome, as it implies that the model is too narrow and has overfit to the specific dataset.

# %%
#In sklearn, an F1-score of 1 means that the model has achieved perfect precision and recall. 
#This means that all of the predictions made by the model were accurate, 
#and that the model was able to identify all of the relevant items in the data set.
